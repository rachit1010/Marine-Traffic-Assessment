# %%
from pygradu import gridify
import shapely.geometry
import pandas as pd
import numpy as np
import importlib

grid = gridify.area_to_grid(side_length=5000)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\user\anaconda3\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# Original NE: POINT (31.5 66.8)
# Original SW: POINT (8.5 53)
# Transformed NE: (697681.2863658136, 7416224.9393330095)
# Transformed SW: (-735260.4063631196, 6033964.466017238)
# col_count 286
# row_count 276
# grid_size 78936

# %%
pip install shapely
# Out:
# Requirement already satisfied: shapely in c:\users\user\anaconda3\lib\site-packages (1.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
from mpl_toolkits.basemap import Basemap

def visualize_graph(graph, grid):
    nodes = graph.original.drop_duplicates().values
    lats = []
    lons = []
    for node in nodes:
        latlon = grid.extract_coords_lat_lon(node)
        lats.append(latlon[0])
        lons.append(latlon[1])


    nodes = graph.connected.drop_duplicates().values
    lats2 = []
    lons2 = []
    for node in nodes:
        latlon = grid.extract_coords_lat_lon(node)
        lats2.append(latlon[0])
        lons2.append(latlon[1])

    f = plt.figure(figsize=[25,25])
    m = Basemap(llcrnrlon = min(lons),llcrnrlat = min(lats), urcrnrlon = max(lons),
               urcrnrlat = max(lats),
               resolution='l')
    m.shadedrelief()

    plt.plot(lons2, lats2, 'o', c='red', alpha=1, markersize=4)
    plt.plot(lons, lats, 'o', c='orange', alpha=1, markersize=4)

    plt.show()
    
def visualize_graph_connections(graph, grid):
    rows = graph.drop_duplicates().values
    lats = []
    lons = []

    m = Basemap(llcrnrlon = min(lons),llcrnrlat = min(lats), urcrnrlon = max(lons),
               urcrnrlat = max(lats),
               resolution='l')
    m.shadedrelief()
    
    f = plt.figure(figsize=[25,25])
    for row in rows:
        original_latlon = grid.extract_coords_lat_lon(row[0])
        connected_latlon = grid.extract_coords_lat_lon(row[1])
        lats = [original_latlon[0], connected_latlon[0]]
        lons = [original_latlon[1], connected_latlon[1]]

        plt.plot(lons, lats, alpha=1, markersize=2, linewidth=1, c='black')


    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-b8d26b62310a> in <module>
#       1 import matplotlib.pyplot as plt
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 3 from mpl_toolkits.basemap import Basemap
#       4
#       5 def visualize_graph(graph, grid):
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'

# %%
pip install mpl_toolkits.basemap
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement mpl_toolkits.basemap (from versions: none)
# ERROR: No matching distribution found for mpl_toolkits.basemap

# %%
conda install basemap
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# Note: you may need to restart the kernel to use updated packages.
# Building graph of deps:   0%|          | 0/5 [00:00<?, ?it/s]
# Examining @/win-64::__cuda==9.1=0:   0%|          | 0/5 [00:00<?, ?it/s]
# Examining basemap:  20%|##        | 1/5 [00:00<00:00, 971.35it/s]
# Examining python=3.8:  40%|####      | 2/5 [00:00<00:00,  3.67it/s]
# Examining python=3.8:  60%|######    | 3/5 [00:00<00:00,  5.51it/s]
# Examining @/win-64::__archspec==1=x86_64:  60%|######    | 3/5 [00:00<00:00,  5.51it/s]
# Examining @/win-64::__archspec==1=x86_64:  80%|########  | 4/5 [00:00<00:00,  5.14it/s]
# Examining @/win-64::__win==0=0:  80%|########  | 4/5 [00:00<00:00,  5.14it/s]
#
#
# Determining conflicts:   0%|          | 0/5 [00:00<?, ?it/s]
# Examining conflict for python basemap:   0%|          | 0/5 [00:00<?, ?it/s]
#
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - basemap -> python[version='>=3.10,<3.11.0a0|>=3.5,<3.6.0a0']
#
# Your python: python=3.8
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.

# %%
conda update python
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working...
# Warning: 2 possible package resolutions (only showing differing packages):
#   - defaults/noarch::sphinx-3.2.1-py_0, defaults/win-64::docutils-0.18.1-py38haa95532_2
#   - defaults/noarch::sphinx-4.4.0-pyhd3eb1b0_0, defaults/win-64::docutils-0.17.1-py38haa95532_1done
#
# ## Package Plan ##
#
#   environment location: C:\Users\user\anaconda3
#
#   added / updated specs:
#     - python
#
#
# The following packages will be downloaded:
#
#
# Note: you may need to restart the kernel to use updated packages.    package                    |            build
#
#     ---------------------------|-----------------
#     beautifulsoup4-4.10.0      |     pyh06a4308_0          85 KB
#     cffi-1.15.0                |   py38h2bbff1b_1         223 KB
#     docutils-0.18.1            |   py38haa95532_2         668 KB
#     html5lib-1.1               |     pyhd3eb1b0_0          91 KB
#     jedi-0.18.0                |   py38haa95532_1         910 KB
#     olefile-0.46               |     pyhd3eb1b0_0          34 KB
# [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2622)
#     path.py-12.5.0             |       hd3eb1b0_0           4 KB
#     pkginfo-1.8.2              |     pyhd3eb1b0_0          27 KB
#     python-slugify-5.0.2       |     pyhd3eb1b0_0          13 KB
#     pyzmq-22.3.0               |   py38hd77b12b_2         627 KB
#     singledispatch-3.7.0       |  pyhd3eb1b0_1001          12 KB
#     sip-4.19.13                |   py38hd77b12b_0         261 KB
#     ------------------------------------------------------------
#                                            Total:         2.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   anyio              pkgs/main/win-64::anyio-2.2.0-py38haa95532_2
#   appdirs            pkgs/main/noarch::appdirs-1.4.4-pyhd3eb1b0_0
#   arrow              pkgs/main/win-64::arrow-0.13.1-py38_0
#   binaryornot        pkgs/main/noarch::binaryornot-0.4.4-pyhd3eb1b0_1
#   black              pkgs/main/noarch::black-19.10b0-py_0
#   brotli             pkgs/main/win-64::brotli-1.0.9-ha925a31_2
#   cfitsio            pkgs/main/win-64::cfitsio-3.470-he774522_6
#   charls             pkgs/main/win-64::charls-2.2.0-h6c2663c_0
#   charset-normalizer pkgs/main/noarch::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   conda-pack         pkgs/main/noarch::conda-pack-0.6.0-pyhd3eb1b0_0
#   cookiecutter       pkgs/main/noarch::cookiecutter-1.7.2-pyhd3eb1b0_0
#   daal4py            pkgs/main/win-64::daal4py-2021.4.0-py38h8cb3d55_0
#   dal                pkgs/main/win-64::dal-2021.4.0-haa95532_729
#   dataclasses        pkgs/main/noarch::dataclasses-0.8-pyh6d0b6a4_7
#   debugpy            pkgs/main/win-64::debugpy-1.5.1-py38hd77b12b_0
#   fonttools          pkgs/main/noarch::fonttools-4.25.0-pyhd3eb1b0_0
#   giflib             pkgs/main/win-64::giflib-5.2.1-h62dcd97_0
#   imagecodecs        pkgs/main/win-64::imagecodecs-2021.8.26-py38ha1f97ea_0
#   inflection         pkgs/main/win-64::inflection-0.5.1-py38haa95532_0
#   jinja2-time        pkgs/main/noarch::jinja2-time-0.2.0-pyhd3eb1b0_2
#   jupyter_server     pkgs/main/win-64::jupyter_server-1.4.1-py38haa95532_0
#   jupyterlab_widgets pkgs/main/noarch::jupyterlab_widgets-1.0.0-pyhd3eb1b0_1
#   lcms2              pkgs/main/win-64::lcms2-2.12-h83e58a3_0
#   lerc               pkgs/main/win-64::lerc-3.0-hd77b12b_0
#   libaec             pkgs/main/win-64::libaec-1.0.4-h33f27b4_1
#   libdeflate         pkgs/main/win-64::libdeflate-1.8-h2bbff1b_5
#   libwebp            pkgs/main/win-64::libwebp-1.2.0-h2bbff1b_0
#   libzopfli          pkgs/main/win-64::libzopfli-1.0.3-ha925a31_0
#   matplotlib-inline  pkgs/main/noarch::matplotlib-inline-0.1.2-pyhd3eb1b0_2
#   munkres            pkgs/main/noarch::munkres-1.1.4-py_0
#   mypy_extensions    pkgs/main/win-64::mypy_extensions-0.4.3-py38haa95532_1
#   nbclassic          pkgs/main/noarch::nbclassic-0.2.6-pyhd3eb1b0_0
#   openjpeg           pkgs/main/win-64::openjpeg-2.4.0-h4fc8c34_0
#   pathspec           pkgs/main/noarch::pathspec-0.7.0-py_0
#   poyo               pkgs/main/noarch::poyo-0.5.0-pyhd3eb1b0_0
#   ptyprocess         pkgs/main/noarch::ptyprocess-0.7.0-pyhd3eb1b0_2
#   pyerfa             pkgs/main/win-64::pyerfa-2.0.0-py38h2bbff1b_0
#   pyls-spyder        pkgs/main/noarch::pyls-spyder-0.4.0-pyhd3eb1b0_0
#   python-lsp-black   pkgs/main/noarch::python-lsp-black-1.0.0-pyhd3eb1b0_0
#   python-lsp-jsonrpc pkgs/main/noarch::python-lsp-jsonrpc-1.0.0-pyhd3eb1b0_0
#   python-lsp-server  pkgs/main/noarch::python-lsp-server-1.2.4-pyhd3eb1b0_0
#   python-slugify     pkgs/main/noarch::python-slugify-5.0.2-pyhd3eb1b0_0
#   qstylizer          pkgs/main/noarch::qstylizer-0.1.10-pyhd3eb1b0_0
#   scikit-learn-inte~ pkgs/main/win-64::scikit-learn-intelex-2021.4.0-py38haa95532_0
#   sniffio            pkgs/main/win-64::sniffio-1.2.0-py38haa95532_1
#   tbb4py             pkgs/main/win-64::tbb4py-2021.5.0-py38h59b6b97_0
#   text-unidecode     pkgs/main/noarch::text-unidecode-1.3-pyhd3eb1b0_0
#   textdistance       pkgs/main/noarch::textdistance-4.2.1-pyhd3eb1b0_0
#   three-merge        pkgs/main/noarch::three-merge-0.1.1-pyhd3eb1b0_0
#   tinycss            pkgs/main/noarch::tinycss-0.4-pyhd3eb1b0_1002
#   typed-ast          pkgs/main/win-64::typed-ast-1.4.3-py38h2bbff1b_1
#   unidecode          pkgs/main/noarch::unidecode-1.2.0-pyhd3eb1b0_0
#   whichcraft         pkgs/main/noarch::whichcraft-0.6.1-pyhd3eb1b0_0
#   zfp                pkgs/main/win-64::zfp-0.5.5-hd77b12b_6
#
# The following packages will be REMOVED:
#
#   gmpy2-2.0.8-py38h7edee0f_3
#   libllvm9-9.0.1-h21ff451_0
#   libsodium-1.0.18-h62dcd97_0
#   mpc-1.1.0-h7edee0f_1
#   mpfr-4.0.2-h62dcd97_1
#   mpir-3.0.0-hec2e145_1
#   pandoc-2.11-h9490d1a_0
#   pathtools-0.1.2-py_1
#   python-jsonrpc-server-0.4.0-py_0
#   python-language-server-0.35.1-py_0
#   zeromq-4.3.2-ha925a31_3
#
# The following packages will be UPDATED:
#
#   _anaconda_depends                          2020.07-py38_0 --> 2021.11-py38_0
#   anaconda-client                              1.7.2-py38_0 --> 1.9.0-py38haa95532_0
#   anaconda-project                               0.8.4-py_0 --> 0.10.2-pyhd3eb1b0_0
#   astroid                                      2.4.2-py38_0 --> 2.6.6-py38haa95532_0
#   astropy                              4.0.2-py38he774522_0 --> 5.0-py38hc7d831d_0
#   attrs                                 20.3.0-pyhd3eb1b0_0 --> 21.4.0-pyhd3eb1b0_0
#   autopep8                                       1.5.4-py_0 --> 1.6.0-pyhd3eb1b0_0
#   babel                                  2.8.1-pyhd3eb1b0_0 --> 2.9.1-pyhd3eb1b0_0
#   backports                                        1.0-py_2 --> 1.1-pyhd3eb1b0_0
#   backports.functoo~                             1.6.1-py_0 --> 1.6.4-pyhd3eb1b0_0
#   backports.shutil_~ pkgs/main/win-64::backports.shutil_ge~ --> pkgs/main/noarch::backports.shutil_get_terminal_size-1.0.0-pyhd3eb1b0_3
#   beautifulsoup4                         4.9.3-pyhb0f4dca_0 --> 4.10.0-pyh06a4308_0
#   bitarray                             1.6.1-py38h2bbff1b_0 --> 2.3.5-py38h2bbff1b_0
#   bleach                                         3.2.1-py_0 --> 4.1.0-pyhd3eb1b0_0
#   blosc                                   1.20.1-h7bd577a_0 --> 1.21.0-h19a0ad4_0
#   bokeh                                        2.2.3-py38_0 --> 2.4.2-py38haa95532_0
#   brotlipy                          0.7.0-py38he774522_1000 --> 0.7.0-py38h2bbff1b_1003
#   cffi                                1.14.3-py38h7a1dbc1_0 --> 1.15.0-py38h2bbff1b_1
#   chardet                                   3.0.4-py38_1003 --> 4.0.0-py38haa95532_1003
#   click                                          7.1.2-py_0 --> 8.0.3-pyhd3eb1b0_0
#   cloudpickle                                    1.6.0-py_0 --> 2.0.0-pyhd3eb1b0_0
#   comtypes                                  1.1.7-py38_1001 --> 1.1.10-py38haa95532_1002
#   conda-package-han~                   1.7.2-py38h76e460a_0 --> 1.7.3-py38h8cc25b3_1
#   cryptography                         3.1.1-py38h7a1dbc1_0 --> 36.0.0-py38h21b164f_0
#   curl                                    7.71.1-h2a8f88b_1 --> 7.80.0-h2bbff1b_0
#   cycler             pkgs/main/win-64::cycler-0.10.0-py38_0 --> pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   cython                             0.29.21-py38ha925a31_0 --> 0.29.25-py38h604cdb4_0
#   dask                                          2.30.0-py_0 --> 2021.10.0-pyhd3eb1b0_0
#   dask-core                                     2.30.0-py_0 --> 2021.10.0-pyhd3eb1b0_0
#   decorator                                      4.4.2-py_0 --> 5.1.1-pyhd3eb1b0_0
#   defusedxml                                     0.6.0-py_0 --> 0.7.1-pyhd3eb1b0_0
#   distributed                         2.30.1-py38haa95532_0 --> 2021.10.0-py38haa95532_0
#   docutils                                      0.16-py38_1 --> 0.18.1-py38haa95532_2
#   et_xmlfile         pkgs/main/noarch::et_xmlfile-1.0.1-py~ --> pkgs/main/win-64::et_xmlfile-1.1.0-py38haa95532_0
#   filelock                                      3.0.12-py_0 --> 3.4.2-pyhd3eb1b0_0
#   flake8                                         3.8.4-py_0 --> 3.9.2-pyhd3eb1b0_0
#   fsspec                                         0.8.3-py_0 --> 2022.1.0-pyhd3eb1b0_0
#   gevent                              20.9.0-py38he774522_0 --> 21.8.0-py38h2bbff1b_1
#   greenlet                            0.4.17-py38he774522_0 --> 1.1.1-py38hd77b12b_0
#   idna                                            2.10-py_0 --> 3.3-pyhd3eb1b0_0
#   imagesize                                      1.2.0-py_0 --> 1.3.0-pyhd3eb1b0_0
#   importlib-metadata pkgs/main/noarch::importlib-metadata-~ --> pkgs/main/win-64::importlib-metadata-4.8.2-py38haa95532_0
#   importlib_metadata                                2.0.0-1 --> 4.8.2-hd3eb1b0_0
#   intel-openmp                                   2020.2-254 --> 2021.4.0-haa95532_3556
#   ipykernel                            5.3.4-py38h5ca1d4c_0 --> 6.4.1-py38haa95532_1
#   ipython                             7.19.0-py38hd4e2768_0 --> 7.29.0-py38hd4e2768_0
#   ipython_genutils   pkgs/main/win-64::ipython_genutils-0.~ --> pkgs/main/noarch::ipython_genutils-0.2.0-pyhd3eb1b0_1
#   ipywidgets                                     7.5.1-py_1 --> 7.6.5-pyhd3eb1b0_1
#   isort                                          5.6.4-py_0 --> 5.9.3-pyhd3eb1b0_0
#   itsdangerous                                   1.1.0-py_0 --> 2.0.1-pyhd3eb1b0_0
#   jedi                                        0.17.1-py38_0 --> 0.18.0-py38haa95532_1
#   jinja2                                        2.11.2-py_0 --> 2.11.3-pyhd3eb1b0_0
#   joblib                                        0.17.0-py_0 --> 1.1.0-pyhd3eb1b0_0
#   jpeg                                        9b-hb83a4c4_2 --> 9d-h2bbff1b_0
#   json5                                          0.9.5-py_0 --> 0.9.6-pyhd3eb1b0_0
#   jupyter_client                                 6.1.7-py_0 --> 6.1.12-pyhd3eb1b0_0
#   jupyter_console                                6.2.0-py_0 --> 6.4.0-pyhd3eb1b0_0
#   jupyter_core                                 4.6.3-py38_0 --> 4.9.1-py38haa95532_0
#   jupyterlab                                     2.2.6-py_0 --> 3.2.1-pyhd3eb1b0_1
#   jupyterlab_server                              1.2.0-py_0 --> 2.10.2-pyhd3eb1b0_1
#   keyring                                     21.4.0-py38_1 --> 23.4.0-py38haa95532_0
#   kiwisolver                           1.3.0-py38hd77b12b_0 --> 1.3.1-py38hd77b12b_0
#   krb5                                    1.18.2-hc04afaa_0 --> 1.19.2-h5b6d351_0
#   lazy-object-proxy                    1.4.3-py38he774522_0 --> 1.6.0-py38h2bbff1b_0
#   libcurl                                 7.71.1-h2a8f88b_1 --> 7.80.0-h86230a5_0
#   libtiff                                  4.1.0-h56a325e_1 --> 4.2.0-hd0e1b90_0
#   libxml2                                 2.9.10-hb89e7f3_3 --> 2.9.12-h0ad7f3c_0
#   locket                                       0.2.0-py38_1 --> 0.2.1-py38haa95532_1
#   lxml                                 4.6.1-py38h1350720_0 --> 4.7.1-py38h1985fb9_1
#   lz4-c                                    1.9.2-hf4a77e7_3 --> 1.9.3-h2bbff1b_1
#   matplotlib                                        3.3.2-0 --> 3.5.0-py38haa95532_0
#   matplotlib-base                      3.3.2-py38hba9282a_0 --> 3.5.0-py38h6214cd6_0
#   mkl                                            2020.2-256 --> 2021.4.0-haa95532_640
#   mkl-service                          2.3.0-py38hb782905_0 --> 2.4.0-py38h2bbff1b_0
#   mkl_fft                              1.2.0-py38h45dec08_0 --> 1.3.1-py38h277e83a_0
#   mkl_random                           1.1.1-py38h47e9c7a_0 --> 1.2.2-py38hf11a4ad_0
#   mock                                           4.0.2-py_0 --> 4.0.3-pyhd3eb1b0_0
#   more-itertools                         8.6.0-pyhd3eb1b0_0 --> 8.12.0-pyhd3eb1b0_0
#   mpmath                                       1.1.0-py38_0 --> 1.2.1-py38haa95532_0
#   msgpack-python                       1.0.0-py38h74a9793_1 --> 1.0.2-py38h59b6b97_1
#   nbclient                                       0.5.1-py_0 --> 0.5.3-pyhd3eb1b0_0
#   nbconvert                                    6.0.7-py38_0 --> 6.1.0-py38haa95532_0
#   nbformat                                       5.0.8-py_0 --> 5.1.3-pyhd3eb1b0_0
#   nest-asyncio                           1.4.2-pyhd3eb1b0_0 --> 1.5.1-pyhd3eb1b0_0
#   networkx                                         2.5-py_0 --> 2.6.3-pyhd3eb1b0_0
#   nltk                                             3.5-py_0 --> 3.6.5-pyhd3eb1b0_0
#   nose                  pkgs/main/win-64::nose-1.3.7-py38_2 --> pkgs/main/noarch::nose-1.3.7-pyhd3eb1b0_1008
#   notebook                                     6.1.4-py38_0 --> 6.4.6-py38haa95532_0
#   numexpr                              2.7.1-py38h25d0782_0 --> 2.8.1-py38hb80d3ca_0
#   numpy                               1.19.2-py38hadc3359_0 --> 1.21.2-py38hfca59bb_0
#   numpy-base                          1.19.2-py38ha3acd2a_0 --> 1.21.2-py38h0829f74_0
#   openpyxl                                       3.0.5-py_0 --> 3.0.9-pyhd3eb1b0_0
#   packaging                                       20.4-py_0 --> 21.3-pyhd3eb1b0_0
#   pandas                               1.1.3-py38ha925a31_0 --> 1.3.5-py38h6214cd6_0
#   pandocfilters      pkgs/main/win-64::pandocfilters-1.4.3~ --> pkgs/main/noarch::pandocfilters-1.5.0-pyhd3eb1b0_0
#   paramiko                                       2.7.2-py_0 --> 2.8.1-pyhd3eb1b0_0
#   parso                                          0.7.0-py_0 --> 0.8.3-pyhd3eb1b0_0
#   partd                                          1.1.0-py_0 --> 1.2.0-pyhd3eb1b0_0
#   path                 pkgs/main/win-64::path-15.0.0-py38_0 --> pkgs/main/noarch::path-16.2.0-pyhd3eb1b0_0
#   pathlib2                                     2.3.5-py38_0 --> 2.3.6-py38haa95532_2
#   patsy                                        0.5.1-py38_0 --> 0.5.2-py38haa95532_0
#   pexpect            pkgs/main/win-64::pexpect-4.8.0-py38_0 --> pkgs/main/noarch::pexpect-4.8.0-pyhd3eb1b0_3
#   pickleshare        pkgs/main/win-64::pickleshare-0.7.5-p~ --> pkgs/main/noarch::pickleshare-0.7.5-pyhd3eb1b0_1003
#   pillow                               8.0.1-py38h4fa10fc_0 --> 8.4.0-py38hd45dc43_0
#   pkginfo            pkgs/main/win-64::pkginfo-1.6.1-py38h~ --> pkgs/main/noarch::pkginfo-1.8.2-pyhd3eb1b0_0
#   prometheus_client                              0.8.0-py_0 --> 0.12.0-pyhd3eb1b0_0
#   prompt-toolkit                                 3.0.8-py_0 --> 3.0.20-pyhd3eb1b0_0
#   prompt_toolkit                                    3.0.8-0 --> 3.0.20-hd3eb1b0_0
#   psutil                               5.7.2-py38he774522_0 --> 5.8.0-py38h2bbff1b_1
#   py                                             1.9.0-py_0 --> 1.10.0-pyhd3eb1b0_0
#   pycodestyle                                    2.6.0-py_0 --> 2.7.0-pyhd3eb1b0_0
#   pycparser                                       2.20-py_2 --> 2.21-pyhd3eb1b0_0
#   pycurl                            7.43.0.6-py38h7a1dbc1_0 --> 7.44.1-py38hcd4344a_1
#   pydocstyle                                     5.1.1-py_0 --> 6.1.1-pyhd3eb1b0_0
#   pyflakes                                       2.2.0-py_0 --> 2.3.1-pyhd3eb1b0_0
#   pygments                               2.7.2-pyhd3eb1b0_0 --> 2.10.0-pyhd3eb1b0_0
#   pylint                                       2.6.0-py38_0 --> 2.9.6-py38haa95532_1
#   pyodbc                              4.0.30-py38ha925a31_0 --> 4.0.31-py38hd77b12b_0
#   pyopenssl                                     19.1.0-py_1 --> 21.0.0-pyhd3eb1b0_1
#   pyparsing                                      2.4.7-py_0 --> 3.0.4-pyhd3eb1b0_0
#   pyqt                                 5.9.2-py38ha925a31_4 --> 5.9.2-py38hd77b12b_6
#   pyrsistent                          0.17.3-py38he774522_0 --> 0.18.0-py38h196d8e1_0
#   pytest                                       6.1.1-py38_0 --> 6.2.4-py38haa95532_2
#   python                                   3.8.5-h5fd99cc_1 --> 3.8.12-h6244533_0
#   python-dateutil                                2.8.1-py_0 --> 2.8.2-pyhd3eb1b0_0
#   python-libarchive~                               2.9-py_0 --> 2.9-pyhd3eb1b0_1
#   pytz                                          2020.1-py_0 --> 2021.3-pyhd3eb1b0_0
#   pywin32                                227-py38he774522_1 --> 302-py38h827c3e9_1
#   pyyaml                               5.3.1-py38he774522_1 --> 6.0-py38h2bbff1b_1
#   pyzmq                               19.0.2-py38ha925a31_1 --> 22.3.0-py38hd77b12b_2
#   qdarkstyle                                     2.8.1-py_0 --> 3.0.2-pyhd3eb1b0_0
#   qtawesome                                      1.0.1-py_0 --> 1.0.3-pyhd3eb1b0_0
#   qtconsole                                      4.7.7-py_0 --> 5.1.1-pyhd3eb1b0_0
#   qtpy                                           1.9.0-py_0 --> 1.11.2-pyhd3eb1b0_0
#   regex                           2020.10.15-py38he774522_0 --> 2021.8.3-py38h2bbff1b_0
#   requests                                      2.24.0-py_0 --> 2.27.1-pyhd3eb1b0_0
#   rope                                          0.18.0-py_0 --> 0.21.1-pyhd3eb1b0_0
#   rtree                                0.9.4-py38h21ff451_1 --> 0.9.7-py38h2eaa2aa_1
#   ruamel_yaml                        0.15.87-py38he774522_1 --> 0.15.100-py38h2bbff1b_0
#   scikit-image                        0.17.2-py38h1e1f486_0 --> 0.18.3-py38hf11a4ad_0
#   scikit-learn                        0.23.2-py38h47e9c7a_0 --> 1.0.2-py38hf11a4ad_1
#   scipy                                1.5.2-py38h14eb087_0 --> 1.7.3-py38h0a974cb_0
#   seaborn                                       0.11.0-py_0 --> 0.11.2-pyhd3eb1b0_0
#   send2trash         pkgs/main/win-64::send2trash-1.5.0-py~ --> pkgs/main/noarch::send2trash-1.8.0-pyhd3eb1b0_1
#   setuptools                          50.3.1-py38haa95532_1 --> 58.0.4-py38haa95532_0
#   singledispatch                            3.4.0.3-py_1001 --> 3.7.0-pyhd3eb1b0_1001
#   six                pkgs/main/win-64::six-1.15.0-py38haa9~ --> pkgs/main/noarch::six-1.16.0-pyhd3eb1b0_0
#   snowballstemmer                                2.0.0-py_0 --> 2.2.0-pyhd3eb1b0_0
#   sortedcollections                              1.2.1-py_0 --> 2.1.0-pyhd3eb1b0_0
#   sortedcontainers                               2.2.2-py_0 --> 2.4.0-pyhd3eb1b0_0
#   soupsieve                                      2.0.1-py_0 --> 2.3.1-pyhd3eb1b0_0
#   sphinxcontrib-htm~                             1.0.3-py_0 --> 2.0.0-pyhd3eb1b0_0
#   sphinxcontrib-ser~                             1.1.4-py_0 --> 1.1.5-pyhd3eb1b0_0
#   spyder                                       4.1.5-py38_0 --> 5.1.5-py38haa95532_1
#   spyder-kernels                               1.9.4-py38_0 --> 2.1.3-py38haa95532_0
#   sqlalchemy                          1.3.20-py38h2bbff1b_0 --> 1.4.27-py38h2bbff1b_0
#   sqlite                                  3.33.0-h2a8f88b_0 --> 3.37.0-h2bbff1b_0
#   statsmodels                         0.12.0-py38he774522_0 --> 0.13.0-py38h2bbff1b_0
#   sympy                                1.6.2-py38haa95532_1 --> 1.9-py38haa95532_0
#   terminado                                    0.9.1-py38_0 --> 0.9.4-py38haa95532_0
#   testpath                                       0.4.4-py_0 --> 0.5.0-pyhd3eb1b0_0
#   threadpoolctl                          2.1.0-pyh5ca1d4c_0 --> 2.2.0-pyh0d69192_0
#   tifffile           pkgs/main/win-64::tifffile-2020.10.1-~ --> pkgs/main/noarch::tifffile-2021.7.2-pyhd3eb1b0_2
#   tk                                      8.6.10-he774522_0 --> 8.6.11-h2bbff1b_0
#   toml                                          0.10.1-py_0 --> 0.10.2-pyhd3eb1b0_0
#   toolz                                         0.11.1-py_0 --> 0.11.2-pyhd3eb1b0_0
#   tornado                              6.0.4-py38he774522_1 --> 6.1-py38h2bbff1b_0
#   tqdm                                          4.50.2-py_0 --> 4.62.3-pyhd3eb1b0_1
#   traitlets                                      5.0.5-py_0 --> 5.1.1-pyhd3eb1b0_0
#   typing_extensions                            3.7.4.3-py_0 --> 3.10.0.2-pyh06a4308_0
#   ujson                                4.0.1-py38ha925a31_0 --> 4.0.2-py38hd77b12b_0
#   urllib3                                      1.25.11-py_0 --> 1.26.8-pyhd3eb1b0_0
#   vc                                        14.1-h0510ff6_4 --> 14.2-h21ff451_1
#   vs2015_runtime                     14.16.27012-hf0eaf9b_3 --> 14.27.29016-h5e58377_2
#   watchdog                                    0.10.3-py38_0 --> 2.1.6-py38haa95532_0
#   werkzeug                                       1.0.1-py_0 --> 2.0.2-pyhd3eb1b0_0
#   wheel                                         0.35.1-py_0 --> 0.37.1-pyhd3eb1b0_0
#   wincertstore                                   0.2-py38_0 --> 0.2-py38haa95532_2
#   wrapt                               1.11.2-py38he774522_0 --> 1.12.1-py38he774522_1
#   xlrd                                           1.2.0-py_0 --> 2.0.1-pyhd3eb1b0_0
#   xlsxwriter                                     1.3.7-py_0 --> 3.0.2-pyhd3eb1b0_0
#   xlwings                                     0.20.8-py38_0 --> 0.24.9-py38haa95532_0
#   yapf                                          0.30.0-py_0 --> 0.31.0-pyhd3eb1b0_0
#   zipp                                   3.4.0-pyhd3eb1b0_0 --> 3.7.0-pyhd3eb1b0_0
#   zope.interface                       5.1.2-py38he774522_0 --> 5.4.0-py38h2bbff1b_0
#   zstd                                     1.4.5-h04227a9_0 --> 1.4.9-h19a0ad4_0
#
# The following packages will be DOWNGRADED:
#
#   alabaster                                     0.7.12-py_0 --> 0.7.12-pyhd3eb1b0_0
#   argon2-cffi                         20.1.0-py38he774522_1 --> 20.1.0-py38h2bbff1b_1
#   async_generator                                 1.10-py_0 --> 1.10-pyhd3eb1b0_0
#   backcall                                       0.2.0-py_0 --> 0.2.0-pyhd3eb1b0_0
#   backports.tempfile                               1.0-py_1 --> 1.0-pyhd3eb1b0_1
#   colorama                                       0.4.4-py_0 --> 0.4.4-pyhd3eb1b0_0
#   contextlib2                              0.6.0.post1-py_0 --> 0.6.0.post1-pyhd3eb1b0_0
#   diff-match-patch                            20200713-py_0 --> 20200713-pyhd3eb1b0_0
#   flask                                          1.1.2-py_0 --> 1.1.2-pyhd3eb1b0_0
#   glob2                                            0.7-py_0 --> 0.7-pyhd3eb1b0_0
#   heapdict                                       1.0.1-py_0 --> 1.0.1-pyhd3eb1b0_0
#   html5lib                                         1.1-py_0 --> 1.1-pyhd3eb1b0_0
#   imageio                                        2.9.0-py_0 --> 2.9.0-pyhd3eb1b0_0
#   iniconfig                                      1.1.1-py_0 --> 1.1.1-pyhd3eb1b0_0
#   intervaltree                                   3.1.0-py_0 --> 3.1.0-pyhd3eb1b0_0
#   jdcal                                          1.4.1-py_0 --> 1.4.1-pyhd3eb1b0_0
#   jsonschema                                     3.2.0-py_2 --> 3.2.0-pyhd3eb1b0_2
#   libspatialindex                          1.9.3-h33f27b4_0 --> 1.9.3-h6c2663c_0
#   olefile                                         0.46-py_0 --> 0.46-pyhd3eb1b0_0
#   path.py                                          12.5.0-0 --> 12.5.0-hd3eb1b0_0
#   pluggy                                      0.13.1-py38_0 --> 0.13.1-py38haa95532_0
#   pycosat                              0.6.3-py38he774522_0 --> 0.6.3-py38h2bbff1b_0
#   pysocks                                      1.7.1-py38_0 --> 1.7.1-py38haa95532_0
#   sip                                4.19.13-py38ha925a31_0 --> 4.19.13-py38hd77b12b_0
#   sphinxcontrib-app~                             1.0.2-py_0 --> 1.0.2-pyhd3eb1b0_0
#   sphinxcontrib-dev~                             1.0.2-py_0 --> 1.0.2-pyhd3eb1b0_0
#   sphinxcontrib-jsm~                             1.0.1-py_0 --> 1.0.1-pyhd3eb1b0_0
#   sphinxcontrib-qth~                             1.0.3-py_0 --> 1.0.3-pyhd3eb1b0_0
#   tblib                                          1.7.0-py_0 --> 1.7.0-pyhd3eb1b0_0
#   wcwidth                                        0.2.5-py_0 --> 0.2.5-pyhd3eb1b0_0
#   win_inet_pton                                1.1.0-py38_0 --> 1.1.0-py38haa95532_0
#   xmltodict                                     0.12.0-py_0 --> 0.12.0-pyhd3eb1b0_0
#   zict                                           2.0.0-py_0 --> 2.0.0-pyhd3eb1b0_0
#   zlib                                    1.2.11-h62dcd97_4 --> 1.2.11-h8cc25b3_4
#
#
#
# Downloading and Extracting Packages
#
# html5lib-1.1         | 91 KB     |            |   0%
# html5lib-1.1         | 91 KB     | #7         |  18%
# html5lib-1.1         | 91 KB     | ########## | 100%
# html5lib-1.1         | 91 KB     | ########## | 100%
#
# docutils-0.18.1      | 668 KB    |            |   0%
# docutils-0.18.1      | 668 KB    | #6         |  17%
# docutils-0.18.1      | 668 KB    | ######7    |  67%
# docutils-0.18.1      | 668 KB    | ########## | 100%
#
# singledispatch-3.7.0 | 12 KB     |            |   0%
# singledispatch-3.7.0 | 12 KB     | ########## | 100%
# singledispatch-3.7.0 | 12 KB     | ########## | 100%
#
# cffi-1.15.0          | 223 KB    |            |   0%
# cffi-1.15.0          | 223 KB    | #######1   |  72%
# cffi-1.15.0          | 223 KB    | ########## | 100%
#
# sip-4.19.13          | 261 KB    |            |   0%
# sip-4.19.13          | 261 KB    | ###6       |  37%
# sip-4.19.13          | 261 KB    | ########5  |  86%
# sip-4.19.13          | 261 KB    | ########## | 100%
#
# python-slugify-5.0.2 | 13 KB     |            |   0%
# python-slugify-5.0.2 | 13 KB     | ########## | 100%
# python-slugify-5.0.2 | 13 KB     | ########## | 100%
#
# jedi-0.18.0          | 910 KB    |            |   0%
# jedi-0.18.0          | 910 KB    | 8          |   9%
# jedi-0.18.0          | 910 KB    | ##1        |  21%
# jedi-0.18.0          | 910 KB    | ########## | 100%
# jedi-0.18.0          | 910 KB    | ########## | 100%
#
# beautifulsoup4-4.10. | 85 KB     |            |   0%
# beautifulsoup4-4.10. | 85 KB     | #8         |  19%
# beautifulsoup4-4.10. | 85 KB     | ###7       |  38%
#
# path.py-12.5.0       | 4 KB      |            |   0%
# path.py-12.5.0       | 4 KB      | ########## | 100%
# path.py-12.5.0       | 4 KB      | ########## | 100%
#
# pyzmq-22.3.0         | 627 KB    |            |   0%
# pyzmq-22.3.0         | 627 KB    | ##2        |  23%
# pyzmq-22.3.0         | 627 KB    | ######3    |  64%
# pyzmq-22.3.0         | 627 KB    | #########7 |  97%
# pyzmq-22.3.0         | 627 KB    | ########## | 100%
#
# olefile-0.46         | 34 KB     |            |   0%
# olefile-0.46         | 34 KB     | ########## | 100%
# olefile-0.46         | 34 KB     | ########## | 100%
#
# pkginfo-1.8.2        | 27 KB     |            |   0%
# pkginfo-1.8.2        | 27 KB     | ########## | 100%
# pkginfo-1.8.2        | 27 KB     | ########## | 100%

# %%
conda install basemap
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
# Building graph of deps:   0%|          | 0/5 [00:00<?, ?it/s]
# Examining @/win-64::__archspec==1=x86_64:   0%|          | 0/5 [00:00<?, ?it/s]
# Examining basemap:  20%|##        | 1/5 [00:00<00:00, 988.52it/s]
# Examining python=3.8:  40%|####      | 2/5 [00:00<00:00,  3.59it/s]
# Examining python=3.8:  60%|######    | 3/5 [00:00<00:00,  5.38it/s]
# Examining @/win-64::__cuda==9.1=0:  60%|######    | 3/5 [00:00<00:00,  5.38it/s]
# Examining @/win-64::__cuda==9.1=0:  80%|########  | 4/5 [00:00<00:00,  5.25it/s]
# Examining @/win-64::__win==0=0:  80%|########  | 4/5 [00:00<00:00,  5.25it/s]
#
#
# Determining conflicts:   0%|          | 0/5 [00:00<?, ?it/s]
# Examining conflict for basemap python:   0%|          | 0/5 [00:00<?, ?it/s]
#
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - basemap -> python[version='>=3.10,<3.11.0a0|>=3.5,<3.6.0a0']
#
# Your python: python=3.8
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
# that.

# %%
conda install python=$3.10$
# Out:
# Note: you may need to restart the kernel to use updated packages.
# CondaValueError: invalid package specification: python=3.1$

# %%
conda update conda
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# Solving environment: ...working...
# Warning: 2 possible package resolutions (only showing differing packages):
#   - defaults/noarch::sphinx-3.2.1-py_0, defaults/win-64::docutils-0.18.1-py38haa95532_2
# DEBUG menuinst_win32:__init__(198): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\Users\user\anaconda3', env_name: 'None', mode: 'user', used_mode: 'user'
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\user\anaconda3\pythonw.exe, args are ['C:\\Users\\user\\anaconda3\\cwp.py', 'C:\\Users\\user\\anaconda3', 'C:\\Users\\user\\anaconda3\\pythonw.exe', 'C:\\Users\\user\\anaconda3\\Scripts\\spyder-script.py']
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\user\anaconda3\python.exe, args are ['C:\\Users\\user\\anaconda3\\cwp.py', 'C:\\Users\\user\\anaconda3', 'C:\\Users\\user\\anaconda3\\python.exe', 'C:\\Users\\user\\anaconda3\\Scripts\\spyder-script.py', '--reset']
# DEBUG menuinst_win32:__init__(198): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\Users\user\anaconda3', env_name: 'None', mode: 'user', used_mode: 'user'
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\user\anaconda3\pythonw.exe, args are ['C:\\Users\\user\\anaconda3\\cwp.py', 'C:\\Users\\user\\anaconda3', 'C:\\Users\\user\\anaconda3\\pythonw.exe', 'C:\\Users\\user\\anaconda3\\Scripts\\spyder-script.py']
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\user\anaconda3\python.exe, args are ['C:\\Users\\user\\anaconda3\\cwp.py', 'C:\\Users\\user\\anaconda3', 'C:\\Users\\user\\anaconda3\\python.exe', 'C:\\Users\\user\\anaconda3\\Scripts\\spyder-script.py', '--reset']
# DEBUG menuinst_win32:__init__(198): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\Users\user\anaconda3', env_name: 'None', mode: 'user', used_mode: 'user'
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\user\anaconda3\python.exe, args are ['C:\\Users\\user\\anaconda3\\cwp.py', 'C:\\Users\\user\\anaconda3', 'C:\\Users\\user\\anaconda3\\python.exe', 'C:\\Users\\user\\anaconda3\\Scripts\\jupyter-notebook-script.py', '"%USERPROFILE%/"']
# DEBUG menuinst_win32:__init__(198): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\Users\user\anaconda3', env_name: 'None', mode: 'user', used_mode: 'user'
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\user\anaconda3\python.exe, args are ['C:\\Users\\user\\anaconda3\\cwp.py', 'C:\\Users\\user\\anaconda3', 'C:\\Users\\user\\anaconda3\\python.exe', 'C:\\Users\\user\\anaconda3\\Scripts\\jupyter-notebook-script.py', '"%USERPROFILE%/"']
# DEBUG menuinst_win32:__init__(198): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\Users\user\anaconda3', env_name: 'None', mode: 'user', used_mode: 'user'
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\user\anaconda3\python.exe, args are ['C:\\Users\\user\\anaconda3\\cwp.py', 'C:\\Users\\user\\anaconda3', 'C:\\Users\\user\\anaconda3\\python.exe', 'C:\\Users\\user\\anaconda3\\Scripts\\jupyter-notebook-script.py', '"%USERPROFILE%/"']
# DEBUG menuinst_win32:__init__(198): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\Users\user\anaconda3', env_name: 'None', mode: 'user', used_mode: 'user'
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\user\anaconda3\pythonw.exe, args are ['C:\\Users\\user\\anaconda3\\cwp.py', 'C:\\Users\\user\\anaconda3', 'C:\\Users\\user\\anaconda3\\pythonw.exe', 'C:\\Users\\user\\anaconda3\\Scripts\\spyder-script.py']
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\user\anaconda3\python.exe, args are ['C:\\Users\\user\\anaconda3\\cwp.py', 'C:\\Users\\user\\anaconda3', 'C:\\Users\\user\\anaconda3\\python.exe', 'C:\\Users\\user\\anaconda3\\Scripts\\spyder-script.py', '--reset']
#   - defaults/noarch::sphinx-4.4.0-pyhd3eb1b0_0, defaults/win-64::docutils-0.17.1-py38haa95532_1done
#
# ## Package Plan ##
#
#   environment location: C:\Users\user\anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     beautifulsoup4-4.10.0      |     pyh06a4308_0          85 KB
#     ------------------------------------------------------------
#                                            Total:          85 KB
#
# The following NEW packages will be INSTALLED:
#
#   anyio              pkgs/main/win-64::anyio-2.2.0-py38haa95532_2
#   appdirs            pkgs/main/noarch::appdirs-1.4.4-pyhd3eb1b0_0
#   arrow              pkgs/main/win-64::arrow-0.13.1-py38_0
#   binaryornot        pkgs/main/noarch::binaryornot-0.4.4-pyhd3eb1b0_1
#   black              pkgs/main/noarch::black-19.10b0-py_0
#   brotli             pkgs/main/win-64::brotli-1.0.9-ha925a31_2
#   cfitsio            pkgs/main/win-64::cfitsio-3.470-he774522_6
#   charls             pkgs/main/win-64::charls-2.2.0-h6c2663c_0
#   charset-normalizer pkgs/main/noarch::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   conda-pack         pkgs/main/noarch::conda-pack-0.6.0-pyhd3eb1b0_0
#   cookiecutter       pkgs/main/noarch::cookiecutter-1.7.2-pyhd3eb1b0_0
#   daal4py            pkgs/main/win-64::daal4py-2021.4.0-py38h8cb3d55_0
#   dal                pkgs/main/win-64::dal-2021.4.0-haa95532_729
#   dataclasses        pkgs/main/noarch::dataclasses-0.8-pyh6d0b6a4_7
#   debugpy            pkgs/main/win-64::debugpy-1.5.1-py38hd77b12b_0
#   fonttools          pkgs/main/noarch::fonttools-4.25.0-pyhd3eb1b0_0
#   giflib             pkgs/main/win-64::giflib-5.2.1-h62dcd97_0
#   imagecodecs        pkgs/main/win-64::imagecodecs-2021.8.26-py38ha1f97ea_0
#   inflection         pkgs/main/win-64::inflection-0.5.1-py38haa95532_0
#   jinja2-time        pkgs/main/noarch::jinja2-time-0.2.0-pyhd3eb1b0_2
#   jupyter_server     pkgs/main/win-64::jupyter_server-1.4.1-py38haa95532_0
#   jupyterlab_widgets pkgs/main/noarch::jupyterlab_widgets-1.0.0-pyhd3eb1b0_1
#   lcms2              pkgs/main/win-64::lcms2-2.12-h83e58a3_0
#   lerc               pkgs/main/win-64::lerc-3.0-hd77b12b_0
#   libaec             pkgs/main/win-64::libaec-1.0.4-h33f27b4_1
#   libdeflate         pkgs/main/win-64::libdeflate-1.8-h2bbff1b_5
#   libwebp            pkgs/main/win-64::libwebp-1.2.0-h2bbff1b_0
#   libzopfli          pkgs/main/win-64::libzopfli-1.0.3-ha925a31_0
#   matplotlib-inline  pkgs/main/noarch::matplotlib-inline-0.1.2-pyhd3eb1b0_2
#   munkres            pkgs/main/noarch::munkres-1.1.4-py_0
#   mypy_extensions    pkgs/main/win-64::mypy_extensions-0.4.3-py38haa95532_1
#   nbclassic          pkgs/main/noarch::nbclassic-0.2.6-pyhd3eb1b0_0
#   openjpeg           pkgs/main/win-64::openjpeg-2.4.0-h4fc8c34_0
#   pathspec           pkgs/main/noarch::pathspec-0.7.0-py_0
#   poyo               pkgs/main/noarch::poyo-0.5.0-pyhd3eb1b0_0
#   ptyprocess         pkgs/main/noarch::ptyprocess-0.7.0-pyhd3eb1b0_2
#   pyerfa             pkgs/main/win-64::pyerfa-2.0.0-py38h2bbff1b_0
#   pyls-spyder        pkgs/main/noarch::pyls-spyder-0.4.0-pyhd3eb1b0_0
#   python-lsp-black   pkgs/main/noarch::python-lsp-black-1.0.0-pyhd3eb1b0_0
#   python-lsp-jsonrpc pkgs/main/noarch::python-lsp-jsonrpc-1.0.0-pyhd3eb1b0_0
#   python-lsp-server  pkgs/main/noarch::python-lsp-server-1.2.4-pyhd3eb1b0_0
#   python-slugify     pkgs/main/noarch::python-slugify-5.0.2-pyhd3eb1b0_0
#   qstylizer          pkgs/main/noarch::qstylizer-0.1.10-pyhd3eb1b0_0
#   scikit-learn-inte~ pkgs/main/win-64::scikit-learn-intelex-2021.4.0-py38haa95532_0
#   sniffio            pkgs/main/win-64::sniffio-1.2.0-py38haa95532_1
#   tbb4py             pkgs/main/win-64::tbb4py-2021.5.0-py38h59b6b97_0
#   text-unidecode     pkgs/main/noarch::text-unidecode-1.3-pyhd3eb1b0_0
#   textdistance       pkgs/main/noarch::textdistance-4.2.1-pyhd3eb1b0_0
#   three-merge        pkgs/main/noarch::three-merge-0.1.1-pyhd3eb1b0_0
#   tinycss            pkgs/main/noarch::tinycss-0.4-pyhd3eb1b0_1002
#   typed-ast          pkgs/main/win-64::typed-ast-1.4.3-py38h2bbff1b_1
#   unidecode          pkgs/main/noarch::unidecode-1.2.0-pyhd3eb1b0_0
#   whichcraft         pkgs/main/noarch::whichcraft-0.6.1-pyhd3eb1b0_0
#   zfp                pkgs/main/win-64::zfp-0.5.5-hd77b12b_6
#
# The following packages will be REMOVED:
#
#   gmpy2-2.0.8-py38h7edee0f_3
#   libllvm9-9.0.1-h21ff451_0
#   libsodium-1.0.18-h62dcd97_0
#   mpc-1.1.0-h7edee0f_1
#   mpfr-4.0.2-h62dcd97_1
#   mpir-3.0.0-hec2e145_1
#   pandoc-2.11-h9490d1a_0
#   pathtools-0.1.2-py_1
#   python-jsonrpc-server-0.4.0-py_0
#   python-language-server-0.35.1-py_0
#   zeromq-4.3.2-ha925a31_3
#
# The following packages will be UPDATED:
#
#   _anaconda_depends                          2020.07-py38_0 --> 2021.11-py38_0
#   anaconda-client                              1.7.2-py38_0 --> 1.9.0-py38haa95532_0
#   anaconda-project                               0.8.4-py_0 --> 0.10.2-pyhd3eb1b0_0
#   astroid                                      2.4.2-py38_0 --> 2.6.6-py38haa95532_0
#   astropy                              4.0.2-py38he774522_0 --> 5.0-py38hc7d831d_0
#   attrs                                 20.3.0-pyhd3eb1b0_0 --> 21.4.0-pyhd3eb1b0_0
#   autopep8                                       1.5.4-py_0 --> 1.6.0-pyhd3eb1b0_0
#   babel                                  2.8.1-pyhd3eb1b0_0 --> 2.9.1-pyhd3eb1b0_0
#   backports                                        1.0-py_2 --> 1.1-pyhd3eb1b0_0
#   backports.functoo~                             1.6.1-py_0 --> 1.6.4-pyhd3eb1b0_0
#   backports.shutil_~ pkgs/main/win-64::backports.shutil_ge~ --> pkgs/main/noarch::backports.shutil_get_terminal_size-1.0.0-pyhd3eb1b0_3
#   beautifulsoup4                         4.9.3-pyhb0f4dca_0 --> 4.10.0-pyh06a4308_0
#   bitarray                             1.6.1-py38h2bbff1b_0 --> 2.3.5-py38h2bbff1b_0
#   bleach                                         3.2.1-py_0 --> 4.1.0-pyhd3eb1b0_0
#   blosc                                   1.20.1-h7bd577a_0 --> 1.21.0-h19a0ad4_0
#   bokeh                                        2.2.3-py38_0 --> 2.4.2-py38haa95532_0
#   brotlipy                          0.7.0-py38he774522_1000 --> 0.7.0-py38h2bbff1b_1003
#   cffi                                1.14.3-py38h7a1dbc1_0 --> 1.15.0-py38h2bbff1b_1
#   chardet                                   3.0.4-py38_1003 --> 4.0.0-py38haa95532_1003
#   click                                          7.1.2-py_0 --> 8.0.3-pyhd3eb1b0_0
#   cloudpickle                                    1.6.0-py_0 --> 2.0.0-pyhd3eb1b0_0
#   comtypes                                  1.1.7-py38_1001 --> 1.1.10-py38haa95532_1002
#   conda-package-han~                   1.7.2-py38h76e460a_0 --> 1.7.3-py38h8cc25b3_1
#   cryptography                         3.1.1-py38h7a1dbc1_0 --> 36.0.0-py38h21b164f_0
#   curl                                    7.71.1-h2a8f88b_1 --> 7.80.0-h2bbff1b_0
#   cycler             pkgs/main/win-64::cycler-0.10.0-py38_0 --> pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   cython                             0.29.21-py38ha925a31_0 --> 0.29.25-py38h604cdb4_0
#   dask                                          2.30.0-py_0 --> 2021.10.0-pyhd3eb1b0_0
#   dask-core                                     2.30.0-py_0 --> 2021.10.0-pyhd3eb1b0_0
#   decorator                                      4.4.2-py_0 --> 5.1.1-pyhd3eb1b0_0
#   defusedxml                                     0.6.0-py_0 --> 0.7.1-pyhd3eb1b0_0
#   distributed                         2.30.1-py38haa95532_0 --> 2021.10.0-py38haa95532_0
#   docutils                                      0.16-py38_1 --> 0.18.1-py38haa95532_2
#   et_xmlfile         pkgs/main/noarch::et_xmlfile-1.0.1-py~ --> pkgs/main/win-64::et_xmlfile-1.1.0-py38haa95532_0
#   filelock                                      3.0.12-py_0 --> 3.4.2-pyhd3eb1b0_0
#   flake8                                         3.8.4-py_0 --> 3.9.2-pyhd3eb1b0_0
#   fsspec                                         0.8.3-py_0 --> 2022.1.0-pyhd3eb1b0_0
#   gevent                              20.9.0-py38he774522_0 --> 21.8.0-py38h2bbff1b_1
#   greenlet                            0.4.17-py38he774522_0 --> 1.1.1-py38hd77b12b_0
#   idna                                            2.10-py_0 --> 3.3-pyhd3eb1b0_0
#   imagesize                                      1.2.0-py_0 --> 1.3.0-pyhd3eb1b0_0
#   importlib-metadata pkgs/main/noarch::importlib-metadata-~ --> pkgs/main/win-64::importlib-metadata-4.8.2-py38haa95532_0
#   importlib_metadata                                2.0.0-1 --> 4.8.2-hd3eb1b0_0
#   intel-openmp                                   2020.2-254 --> 2021.4.0-haa95532_3556
#   ipykernel                            5.3.4-py38h5ca1d4c_0 --> 6.4.1-py38haa95532_1
#   ipython                             7.19.0-py38hd4e2768_0 --> 7.29.0-py38hd4e2768_0
#   ipython_genutils   pkgs/main/win-64::ipython_genutils-0.~ --> pkgs/main/noarch::ipython_genutils-0.2.0-pyhd3eb1b0_1
#   ipywidgets                                     7.5.1-py_1 --> 7.6.5-pyhd3eb1b0_1
#   isort                                          5.6.4-py_0 --> 5.9.3-pyhd3eb1b0_0
#   itsdangerous                                   1.1.0-py_0 --> 2.0.1-pyhd3eb1b0_0
#   jedi                                        0.17.1-py38_0 --> 0.18.0-py38haa95532_1
#   jinja2                                        2.11.2-py_0 --> 2.11.3-pyhd3eb1b0_0
#   joblib                                        0.17.0-py_0 --> 1.1.0-pyhd3eb1b0_0
#   jpeg                                        9b-hb83a4c4_2 --> 9d-h2bbff1b_0
#   json5                                          0.9.5-py_0 --> 0.9.6-pyhd3eb1b0_0
#   jupyter_client                                 6.1.7-py_0 --> 6.1.12-pyhd3eb1b0_0
#   jupyter_console                                6.2.0-py_0 --> 6.4.0-pyhd3eb1b0_0
#   jupyter_core                                 4.6.3-py38_0 --> 4.9.1-py38haa95532_0
#   jupyterlab                                     2.2.6-py_0 --> 3.2.1-pyhd3eb1b0_1
#   jupyterlab_server                              1.2.0-py_0 --> 2.10.2-pyhd3eb1b0_1
#   keyring                                     21.4.0-py38_1 --> 23.4.0-py38haa95532_0
#   kiwisolver                           1.3.0-py38hd77b12b_0 --> 1.3.1-py38hd77b12b_0
#   krb5                                    1.18.2-hc04afaa_0 --> 1.19.2-h5b6d351_0
#   lazy-object-proxy                    1.4.3-py38he774522_0 --> 1.6.0-py38h2bbff1b_0
#   libcurl                                 7.71.1-h2a8f88b_1 --> 7.80.0-h86230a5_0
#   libtiff                                  4.1.0-h56a325e_1 --> 4.2.0-hd0e1b90_0
#   libxml2                                 2.9.10-hb89e7f3_3 --> 2.9.12-h0ad7f3c_0
#   locket                                       0.2.0-py38_1 --> 0.2.1-py38haa95532_1
#   lxml                                 4.6.1-py38h1350720_0 --> 4.7.1-py38h1985fb9_1
#   lz4-c                                    1.9.2-hf4a77e7_3 --> 1.9.3-h2bbff1b_1
#   matplotlib                                        3.3.2-0 --> 3.5.0-py38haa95532_0
#   matplotlib-base                      3.3.2-py38hba9282a_0 --> 3.5.0-py38h6214cd6_0
#   mkl                                            2020.2-256 --> 2021.4.0-haa95532_640
#   mkl-service                          2.3.0-py38hb782905_0 --> 2.4.0-py38h2bbff1b_0
#   mkl_fft                              1.2.0-py38h45dec08_0 --> 1.3.1-py38h277e83a_0
#   mkl_random                           1.1.1-py38h47e9c7a_0 --> 1.2.2-py38hf11a4ad_0
#   mock                                           4.0.2-py_0 --> 4.0.3-pyhd3eb1b0_0
#   more-itertools                         8.6.0-pyhd3eb1b0_0 --> 8.12.0-pyhd3eb1b0_0
#   mpmath                                       1.1.0-py38_0 --> 1.2.1-py38haa95532_0
#   msgpack-python                       1.0.0-py38h74a9793_1 --> 1.0.2-py38h59b6b97_1
#   nbclient                                       0.5.1-py_0 --> 0.5.3-pyhd3eb1b0_0
#   nbconvert                                    6.0.7-py38_0 --> 6.1.0-py38haa95532_0
#   nbformat                                       5.0.8-py_0 --> 5.1.3-pyhd3eb1b0_0
#   nest-asyncio                           1.4.2-pyhd3eb1b0_0 --> 1.5.1-pyhd3eb1b0_0
#   networkx                                         2.5-py_0 --> 2.6.3-pyhd3eb1b0_0
#   nltk                                             3.5-py_0 --> 3.6.5-pyhd3eb1b0_0
#   nose                  pkgs/main/win-64::nose-1.3.7-py38_2 --> pkgs/main/noarch::nose-1.3.7-pyhd3eb1b0_1008
#   notebook                                     6.1.4-py38_0 --> 6.4.6-py38haa95532_0
#   numexpr                              2.7.1-py38h25d0782_0 --> 2.8.1-py38hb80d3ca_0
#   numpy                               1.19.2-py38hadc3359_0 --> 1.21.2-py38hfca59bb_0
#   numpy-base                          1.19.2-py38ha3acd2a_0 --> 1.21.2-py38h0829f74_0
#   openpyxl                                       3.0.5-py_0 --> 3.0.9-pyhd3eb1b0_0
#   packaging                                       20.4-py_0 --> 21.3-pyhd3eb1b0_0
#   pandas                               1.1.3-py38ha925a31_0 --> 1.3.5-py38h6214cd6_0
#   pandocfilters      pkgs/main/win-64::pandocfilters-1.4.3~ --> pkgs/main/noarch::pandocfilters-1.5.0-pyhd3eb1b0_0
#   paramiko                                       2.7.2-py_0 --> 2.8.1-pyhd3eb1b0_0
#   parso                                          0.7.0-py_0 --> 0.8.3-pyhd3eb1b0_0
#   partd                                          1.1.0-py_0 --> 1.2.0-pyhd3eb1b0_0
#   path                 pkgs/main/win-64::path-15.0.0-py38_0 --> pkgs/main/noarch::path-16.2.0-pyhd3eb1b0_0
#   pathlib2                                     2.3.5-py38_0 --> 2.3.6-py38haa95532_2
#   patsy                                        0.5.1-py38_0 --> 0.5.2-py38haa95532_0
#   pexpect            pkgs/main/win-64::pexpect-4.8.0-py38_0 --> pkgs/main/noarch::pexpect-4.8.0-pyhd3eb1b0_3
#   pickleshare        pkgs/main/win-64::pickleshare-0.7.5-p~ --> pkgs/main/noarch::pickleshare-0.7.5-pyhd3eb1b0_1003
#   pillow                               8.0.1-py38h4fa10fc_0 --> 8.4.0-py38hd45dc43_0
#   pkginfo            pkgs/main/win-64::pkginfo-1.6.1-py38h~ --> pkgs/main/noarch::pkginfo-1.8.2-pyhd3eb1b0_0
#   prometheus_client                              0.8.0-py_0 --> 0.12.0-pyhd3eb1b0_0
#   prompt-toolkit                                 3.0.8-py_0 --> 3.0.20-pyhd3eb1b0_0
#   prompt_toolkit                                    3.0.8-0 --> 3.0.20-hd3eb1b0_0
#   psutil                               5.7.2-py38he774522_0 --> 5.8.0-py38h2bbff1b_1
#   py                                             1.9.0-py_0 --> 1.10.0-pyhd3eb1b0_0
#   pycodestyle                                    2.6.0-py_0 --> 2.7.0-pyhd3eb1b0_0
#   pycparser                                       2.20-py_2 --> 2.21-pyhd3eb1b0_0
#   pycurl                            7.43.0.6-py38h7a1dbc1_0 --> 7.44.1-py38hcd4344a_1
#   pydocstyle                                     5.1.1-py_0 --> 6.1.1-pyhd3eb1b0_0
#   pyflakes                                       2.2.0-py_0 --> 2.3.1-pyhd3eb1b0_0
#   pygments                               2.7.2-pyhd3eb1b0_0 --> 2.10.0-pyhd3eb1b0_0
#   pylint                                       2.6.0-py38_0 --> 2.9.6-py38haa95532_1
#   pyodbc                              4.0.30-py38ha925a31_0 --> 4.0.31-py38hd77b12b_0
#   pyopenssl                                     19.1.0-py_1 --> 21.0.0-pyhd3eb1b0_1
#   pyparsing                                      2.4.7-py_0 --> 3.0.4-pyhd3eb1b0_0
#   pyqt                                 5.9.2-py38ha925a31_4 --> 5.9.2-py38hd77b12b_6
#   pyrsistent                          0.17.3-py38he774522_0 --> 0.18.0-py38h196d8e1_0
#   pytest                                       6.1.1-py38_0 --> 6.2.4-py38haa95532_2
#   python-dateutil                                2.8.1-py_0 --> 2.8.2-pyhd3eb1b0_0
#   python-libarchive~                               2.9-py_0 --> 2.9-pyhd3eb1b0_1
#   pytz                                          2020.1-py_0 --> 2021.3-pyhd3eb1b0_0
#   pywin32                                227-py38he774522_1 --> 302-py38h827c3e9_1
#   pyyaml                               5.3.1-py38he774522_1 --> 6.0-py38h2bbff1b_1
#   pyzmq                               19.0.2-py38ha925a31_1 --> 22.3.0-py38hd77b12b_2
#   qdarkstyle                                     2.8.1-py_0 --> 3.0.2-pyhd3eb1b0_0
#   qtawesome                                      1.0.1-py_0 --> 1.0.3-pyhd3eb1b0_0
#   qtconsole                                      4.7.7-py_0 --> 5.1.1-pyhd3eb1b0_0
#   qtpy                                           1.9.0-py_0 --> 1.11.2-pyhd3eb1b0_0
#   regex                           2020.10.15-py38he774522_0 --> 2021.8.3-py38h2bbff1b_0
#   requests                                      2.24.0-py_0 --> 2.27.1-pyhd3eb1b0_0
#   rope                                          0.18.0-py_0 --> 0.21.1-pyhd3eb1b0_0
#   rtree                                0.9.4-py38h21ff451_1 --> 0.9.7-py38h2eaa2aa_1
#   ruamel_yaml                        0.15.87-py38he774522_1 --> 0.15.100-py38h2bbff1b_0
#   scikit-image                        0.17.2-py38h1e1f486_0 --> 0.18.3-py38hf11a4ad_0
#   scikit-learn                        0.23.2-py38h47e9c7a_0 --> 1.0.2-py38hf11a4ad_1
#   scipy                                1.5.2-py38h14eb087_0 --> 1.7.3-py38h0a974cb_0
#   seaborn                                       0.11.0-py_0 --> 0.11.2-pyhd3eb1b0_0
#   send2trash         pkgs/main/win-64::send2trash-1.5.0-py~ --> pkgs/main/noarch::send2trash-1.8.0-pyhd3eb1b0_1
#   setuptools                          50.3.1-py38haa95532_1 --> 58.0.4-py38haa95532_0
#   singledispatch                            3.4.0.3-py_1001 --> 3.7.0-pyhd3eb1b0_1001
#   six                pkgs/main/win-64::six-1.15.0-py38haa9~ --> pkgs/main/noarch::six-1.16.0-pyhd3eb1b0_0
#   snowballstemmer                                2.0.0-py_0 --> 2.2.0-pyhd3eb1b0_0
#   sortedcollections                              1.2.1-py_0 --> 2.1.0-pyhd3eb1b0_0
#   sortedcontainers                               2.2.2-py_0 --> 2.4.0-pyhd3eb1b0_0
#   soupsieve                                      2.0.1-py_0 --> 2.3.1-pyhd3eb1b0_0
#   sphinxcontrib-htm~                             1.0.3-py_0 --> 2.0.0-pyhd3eb1b0_0
#   sphinxcontrib-ser~                             1.1.4-py_0 --> 1.1.5-pyhd3eb1b0_0
#   spyder                                       4.1.5-py38_0 --> 5.1.5-py38haa95532_1
#   spyder-kernels                               1.9.4-py38_0 --> 2.1.3-py38haa95532_0
#   sqlalchemy                          1.3.20-py38h2bbff1b_0 --> 1.4.27-py38h2bbff1b_0
#   sqlite                                  3.33.0-h2a8f88b_0 --> 3.37.0-h2bbff1b_0
#   statsmodels                         0.12.0-py38he774522_0 --> 0.13.0-py38h2bbff1b_0
#   sympy                                1.6.2-py38haa95532_1 --> 1.9-py38haa95532_0
#   terminado                                    0.9.1-py38_0 --> 0.9.4-py38haa95532_0
#   testpath                                       0.4.4-py_0 --> 0.5.0-pyhd3eb1b0_0
#   threadpoolctl                          2.1.0-pyh5ca1d4c_0 --> 2.2.0-pyh0d69192_0
#   tifffile           pkgs/main/win-64::tifffile-2020.10.1-~ --> pkgs/main/noarch::tifffile-2021.7.2-pyhd3eb1b0_2
#   tk                                      8.6.10-he774522_0 --> 8.6.11-h2bbff1b_0
#   toml                                          0.10.1-py_0 --> 0.10.2-pyhd3eb1b0_0
#   toolz                                         0.11.1-py_0 --> 0.11.2-pyhd3eb1b0_0
#   tornado                              6.0.4-py38he774522_1 --> 6.1-py38h2bbff1b_0
#   tqdm                                          4.50.2-py_0 --> 4.62.3-pyhd3eb1b0_1
#   traitlets                                      5.0.5-py_0 --> 5.1.1-pyhd3eb1b0_0
#   typing_extensions                            3.7.4.3-py_0 --> 3.10.0.2-pyh06a4308_0
#   ujson                                4.0.1-py38ha925a31_0 --> 4.0.2-py38hd77b12b_0
#   urllib3                                      1.25.11-py_0 --> 1.26.8-pyhd3eb1b0_0
#   vc                                        14.1-h0510ff6_4 --> 14.2-h21ff451_1
#   vs2015_runtime                     14.16.27012-hf0eaf9b_3 --> 14.27.29016-h5e58377_2
#   watchdog                                    0.10.3-py38_0 --> 2.1.6-py38haa95532_0
#   werkzeug                                       1.0.1-py_0 --> 2.0.2-pyhd3eb1b0_0
#   wheel                                         0.35.1-py_0 --> 0.37.1-pyhd3eb1b0_0
#   wincertstore                                   0.2-py38_0 --> 0.2-py38haa95532_2
#   wrapt                               1.11.2-py38he774522_0 --> 1.12.1-py38he774522_1
#   xlrd                                           1.2.0-py_0 --> 2.0.1-pyhd3eb1b0_0
#   xlsxwriter                                     1.3.7-py_0 --> 3.0.2-pyhd3eb1b0_0
#   xlwings                                     0.20.8-py38_0 --> 0.24.9-py38haa95532_0
#   yapf                                          0.30.0-py_0 --> 0.31.0-pyhd3eb1b0_0
#   zipp                                   3.4.0-pyhd3eb1b0_0 --> 3.7.0-pyhd3eb1b0_0
#   zope.interface                       5.1.2-py38he774522_0 --> 5.4.0-py38h2bbff1b_0
#   zstd                                     1.4.5-h04227a9_0 --> 1.4.9-h19a0ad4_0
#
# The following packages will be DOWNGRADED:
#
#   alabaster                                     0.7.12-py_0 --> 0.7.12-pyhd3eb1b0_0
#   argon2-cffi                         20.1.0-py38he774522_1 --> 20.1.0-py38h2bbff1b_1
#   async_generator                                 1.10-py_0 --> 1.10-pyhd3eb1b0_0
#   backcall                                       0.2.0-py_0 --> 0.2.0-pyhd3eb1b0_0
#   backports.tempfile                               1.0-py_1 --> 1.0-pyhd3eb1b0_1
#   colorama                                       0.4.4-py_0 --> 0.4.4-pyhd3eb1b0_0
#   contextlib2                              0.6.0.post1-py_0 --> 0.6.0.post1-pyhd3eb1b0_0
#   diff-match-patch                            20200713-py_0 --> 20200713-pyhd3eb1b0_0
#   flask                                          1.1.2-py_0 --> 1.1.2-pyhd3eb1b0_0
#   glob2                                            0.7-py_0 --> 0.7-pyhd3eb1b0_0
#   heapdict                                       1.0.1-py_0 --> 1.0.1-pyhd3eb1b0_0
#   html5lib                                         1.1-py_0 --> 1.1-pyhd3eb1b0_0
#   imageio                                        2.9.0-py_0 --> 2.9.0-pyhd3eb1b0_0
#   iniconfig                                      1.1.1-py_0 --> 1.1.1-pyhd3eb1b0_0
#   intervaltree                                   3.1.0-py_0 --> 3.1.0-pyhd3eb1b0_0
#   jdcal                                          1.4.1-py_0 --> 1.4.1-pyhd3eb1b0_0
#   jsonschema                                     3.2.0-py_2 --> 3.2.0-pyhd3eb1b0_2
#   libspatialindex                          1.9.3-h33f27b4_0 --> 1.9.3-h6c2663c_0
#   olefile                                         0.46-py_0 --> 0.46-pyhd3eb1b0_0
#   path.py                                          12.5.0-0 --> 12.5.0-hd3eb1b0_0
#   pluggy                                      0.13.1-py38_0 --> 0.13.1-py38haa95532_0
#   pycosat                              0.6.3-py38he774522_0 --> 0.6.3-py38h2bbff1b_0
#   pysocks                                      1.7.1-py38_0 --> 1.7.1-py38haa95532_0
#   sip                                4.19.13-py38ha925a31_0 --> 4.19.13-py38hd77b12b_0
#   sphinxcontrib-app~                             1.0.2-py_0 --> 1.0.2-pyhd3eb1b0_0
#   sphinxcontrib-dev~                             1.0.2-py_0 --> 1.0.2-pyhd3eb1b0_0
#   sphinxcontrib-jsm~                             1.0.1-py_0 --> 1.0.1-pyhd3eb1b0_0
#   sphinxcontrib-qth~                             1.0.3-py_0 --> 1.0.3-pyhd3eb1b0_0
#   tblib                                          1.7.0-py_0 --> 1.7.0-pyhd3eb1b0_0
#   wcwidth                                        0.2.5-py_0 --> 0.2.5-pyhd3eb1b0_0
#   win_inet_pton                                1.1.0-py38_0 --> 1.1.0-py38haa95532_0
#   xmltodict                                     0.12.0-py_0 --> 0.12.0-pyhd3eb1b0_0
#   zict                                           2.0.0-py_0 --> 2.0.0-pyhd3eb1b0_0
#   zlib                                    1.2.11-h62dcd97_4 --> 1.2.11-h8cc25b3_4
#
#
#
# Downloading and Extracting Packages
#
# beautifulsoup4-4.10. | 85 KB     |            |   0%
# beautifulsoup4-4.10. | 85 KB     | #8         |  19%
# beautifulsoup4-4.10. | 85 KB     | ########## | 100%
# beautifulsoup4-4.10. | 85 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Windows 64-bit packages of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
# done

# %%
conda install basemap
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# Note: you may need to restart the kernel to use updated packages.
# Building graph of deps:   0%|          | 0/5 [00:00<?, ?it/s]
# Examining python=3.8:   0%|          | 0/5 [00:00<?, ?it/s]
# Examining basemap:  20%|##        | 1/5 [00:00<00:01,  3.94it/s]
# Examining basemap:  40%|####      | 2/5 [00:00<00:00,  7.88it/s]
# Examining @/win-64::__win==0=0:  40%|####      | 2/5 [00:00<00:00,  7.88it/s]
# Examining @/win-64::__win==0=0:  60%|######    | 3/5 [00:00<00:00,  3.28it/s]
# Examining @/win-64::__cuda==9.1=0:  60%|######    | 3/5 [00:00<00:00,  3.28it/s]
# Examining @/win-64::__archspec==1=x86_64:  80%|########  | 4/5 [00:00<00:00,  3.28it/s]
#
#
# Determining conflicts:   0%|          | 0/5 [00:00<?, ?it/s]
# Examining conflict for python basemap:   0%|          | 0/5 [00:00<?, ?it/s]
#
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - basemap -> python[version='>=3.10,<3.11.0a0|>=3.5,<3.6.0a0']
#
# Your python: python=3.8
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.

# %%
conda update python
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working...
# Warning: 2 possible package resolutions (only showing differing packages):
#   - defaults/noarch::sphinx-3.2.1-py_0, defaults/win-64::docutils-0.18.1-py38haa95532_2
#   - defaults/noarch::sphinx-4.4.0-pyhd3eb1b0_0, defaults/win-64::docutils-0.17.1-py38haa95532_1done
#
# ## Package Plan ##
#
#   environment location: C:\Users\user\anaconda3
#
#   added / updated specs:
#     - python
#
#
# The following packages will be UPDATED:
#
#   python                                   3.8.5-h5fd99cc_1 --> 3.8.12-h6244533_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install basemap
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
# Building graph of deps:   0%|          | 0/5 [00:00<?, ?it/s]
# Examining basemap:   0%|          | 0/5 [00:00<?, ?it/s]
# Examining @/win-64::__archspec==1=x86_64:  20%|##        | 1/5 [00:00<00:02,  1.54it/s]
# Examining @/win-64::__archspec==1=x86_64:  40%|####      | 2/5 [00:00<00:00,  3.08it/s]
# Examining python=3.8:  40%|####      | 2/5 [00:00<00:00,  3.08it/s]
# Examining @/win-64::__win==0=0:  60%|######    | 3/5 [00:00<00:00,  3.08it/s]
# Examining @/win-64::__win==0=0:  80%|########  | 4/5 [00:00<00:00,  4.98it/s]
# Examining @/win-64::__cuda==9.1=0:  80%|########  | 4/5 [00:00<00:00,  4.98it/s]
#
#
# Determining conflicts:   0%|          | 0/5 [00:00<?, ?it/s]
# Examining conflict for basemap python:   0%|          | 0/5 [00:00<?, ?it/s]
#
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - basemap -> python[version='>=3.10,<3.11.0a0|>=3.5,<3.6.0a0']
#
# Your python: python=3.8
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
